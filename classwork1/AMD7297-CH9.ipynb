# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rand

# %%
# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

# Stack design matrix with column of ones for intercept
A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
x_line = np.linspace(0, max(X), 100)
lstsq = m * x_line + c

plt.title("Least Square Regression Between the given Data Points")
#data points
plt.scatter(X, Y)
#this is regression line
plt.plot(x_line, lstsq)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# Randomize vectors X and Y
Xrand = np.random.rand(X.size)
Yrand = np.random.rand(Y.size)

idx = np.argsort(Xrand)
Xrand = Xrand[idx]
Yrand = Yrand[idx]

print("Randomized X Vector:", Xrand)
print("Randomized Y Vector:", Yrand)

B = np.vstack([Xrand, np.ones(len(Xrand))]).T
n, d = np.linalg.lstsq(B, Yrand, rcond=None)[0]

print("Slope:", n, "Intercept:", d)
# Out:
# Randomized X Vector: [0.00628596 0.31586269 0.42670797 0.54816173 0.82372543]
# Randomized Y Vector: [0.83154682 0.88233854 0.90036518 0.96177486 0.02662632]
# Slope: -0.8600345225327342 Intercept: 1.0853129179108445

# %%
X = np.linspace(Xrand.min(), Xrand.max(), 100)
y = n * X + d

plt.title("Least Square Regression Model of Randomized Vectors")
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(Xrand, Yrand)
plt.plot(X, y)
plt.show()

# %%
# Randomization
X1 = np.arange(0, 1.01, 0.01)
m = np.random.rand()
b = np.random.rand()

Y = m * X1 + b + np.random.rand(X1.size)

print("Random Slope:", m, "Random Intercept:", b)
# Out:
# Random Slope: 0.9506429305134558 Random Intercept: 0.41517724073114437

# %%
# Linear algebra
B = np.vstack([X1, np.ones(len(X1))]).T
n, d = np.linalg.lstsq(B, Y, rcond=None)[0]

print("Calculated Slope:", n, "Calculated Intercept:", d)
# Out:
# Calculated Slope: 0.784692899334651 Calculated Intercept: 0.7737112300073758

# %%
#residuals
residuals = Y - (n * X1 + d)

max_residual = np.argmax(residuals)
min_residual = np.argmin(residuals)

print("Max Residual:", residuals[max_residual], "at point X =", X1[max_residual])
print("Min Residual:", residuals[min_residual], "at point X =", X1[min_residual], "\n")

#all residuals
print("Every Residual:")
for i in range(len(residuals)):
    print(residuals[i])
# Out:
# Max Residual: 0.5432114404630908 at point X = 0.93
# Min Residual: -0.5536732268508242 at point X = 0.14
#
# Every Residual:
# 0.3414244541377778
# -0.14404439793581614
# -0.5341718570154317
# -0.16483021467626768
# 0.371843442604917
# 0.32094576088857674
# -0.039099996172333173
# -0.2511417435293001
# 0.32720120726644886
# -0.3573132976011006
# 0.16183092053739467
# -0.3185274995496732
# -0.46341187729048616
# -0.1637786950904181
# -0.5536732268508242
# 0.06606376048336426
# 0.022288060575496815
# 0.15831045089322104
# 0.23930830722878504
# -0.08485762806470942
# -0.012586955373523279
# 0.08543053833695713
# 0.21583247779985526
# 0.15787996612397848
# 0.18336344985579278
# -0.20776183666564985
# 0.34891883080546116
# 0.21153017573075894
# -0.11258582473634682
# 0.22357114144757628
# 0.2474535450735711
# -0.29308530028087176
# 0.3953880400600083
# 0.23707006856408563
# 0.22827390499485767
# -0.3790220693153541
# 0.285094870300602
# -0.13063205596941818
# -0.09179376724110577
# ...

# %%
plt.title("Least Square Regression Model of Own Linear Equation")
plt.xlabel("X")
plt.ylabel("Y")

plt.plot(X1, n * X1 + d)
plt.scatter(X1, Y)

plt.show()
